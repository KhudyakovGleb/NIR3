# %%
from huggingface_hub import login
from secret import HF_TOKEN

login(
  token=HF_TOKEN, 
  add_to_git_credential=True
)

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
# Out:
# CUDA available: True

# %%
from datasets import load_dataset

ds = load_dataset("Glebosol/spb_POS_data")

print(len(ds['train']))
# Out:
# 21996

# %%
ds['train']
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 21996
# })

# %%
from random import randrange

random_id = randrange(len(ds['train']))
ds['train'][random_id]
# Out:
# {'text': ' невский дк стремительно уходящий в забвение', 'label': 7}

# %%
from transformers import AutoTokenizer


model_id = "cointegrated/rubert-tiny2"
tokenizer = AutoTokenizer.from_pretrained(model_id)

def tokenize(batch):
    return tokenizer(batch['text'], padding='max_length', truncation=True, return_tensors="pt")

raw_dataset =  ds.rename_column("label", "labels") 
raw_dataset = raw_dataset.shuffle(seed=23)
tokenized_dataset = raw_dataset.map(tokenize, batched=True,remove_columns=["text"])
tokenized_dataset = tokenized_dataset["train"].train_test_split(test_size=0.2)

print(tokenized_dataset["train"].features.keys())
# Out:
# Map:   0%|          | 0/21996 [00:00<?, ? examples/s]
# dict_keys(['labels', 'input_ids', 'token_type_ids', 'attention_mask'])

# %%
from transformers import AutoModelForSequenceClassification


model_id = "cointegrated/rubert-tiny2"


labels = tokenized_dataset["train"].features["labels"].names
num_labels = len(labels)
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = str(i)
    id2label[str(i)] = label

model = AutoModelForSequenceClassification.from_pretrained(
    model_id, num_labels=num_labels, label2id=label2id, id2label=id2label
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at cointegrated/rubert-tiny2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import evaluate
import numpy as np


metric = evaluate.load("f1")


def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return metric.compute(predictions=predictions, references=labels, average="weighted")

# %%
from huggingface_hub import HfFolder
from transformers import Trainer, TrainingArguments
import torch._dynamo
torch._dynamo.config.suppress_errors = True

# Id for remote repository
repository_id = "Glebosol/spb_city_prob_class"

# Define training args
training_args = TrainingArguments(
    output_dir=repository_id,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=4,
    learning_rate=5e-5,
	num_train_epochs=3,
	# PyTorch 2.0 specifics
    bf16=True, # bfloat16 training
	torch_compile=True, # optimizations
    optim="adamw_torch_fused", # improved optimizer
    # logging & evaluation strategies
    logging_dir=f"{repository_id}/logs",
    logging_strategy="steps",
    logging_steps=200,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    save_total_limit=2,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    # push to hub parameters
    report_to="tensorboard",
    push_to_hub=True,
    hub_strategy="every_save",
    hub_model_id=repository_id,
    hub_token=HfFolder.get_token(),

)

# Create a Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["test"],
    compute_metrics=compute_metrics,
)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer.train()
# Out:
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bert\modeling_bert.py line 1636
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 588, in aot_dispatch_autograd
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1749, in STORE_ATTR
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.store_attr_graph_break(inst)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1775, in store_attr_graph_break
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py", line 2234, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 1521, in compile_fx
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return aot_autograd(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\backends\common.py", line 72, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     cg = aot_module_simplified(gm, example_inputs, **self.kwargs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1071, in aot_module_simplified
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = dispatch_and_compile()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\aot_autograd.py", line 1056, in dispatch_and_compile
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, _ = create_aot_dispatcher_function(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\aot_autograd.py", line 522, in create_aot_dispatcher_function
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _create_aot_dispatcher_function(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\aot_autograd.py", line 759, in _create_aot_dispatcher_function
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn, fw_metadata = compiler_fn(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                                ^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 588, in aot_dispatch_autograd
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 1350, in fw_compiler_base
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _fw_compiler_base(model, example_inputs, is_inference)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 1421, in _fw_compiler_base
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return inner_compile(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 475, in compile_fx_inner
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return wrap_compiler_debug(_compile_fx_inner, compiler_name="inductor")(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 85, in debug_wrapper
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 661, in _compile_fx_inner
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1749, in STORE_ATTR
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.store_attr_graph_break(inst)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 1775, in store_attr_graph_break
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0123 20:54:39.097000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0123 20:54:41.597000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] WON'T CONVERT forward c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\bert\modeling_bert.py line 1001
# W0123 20:54:41.597000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] due to:
# W0123 20:54:41.597000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0123 20:54:41.597000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1446, in _call_user_compiler
# W0123 20:54:41.597000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0123 20:54:41.597000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0123 20:54:41.597000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 129, in __call__
# W0123 20:54:41.597000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_gm = compiler_fn(gm, example_inputs)
# W0123 20:54:41.597000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = FxGraphCache.load(
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\codecache.py", line 1334, in load
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = compile_fx_fn(
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 570, in codegen_and_compile
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_graph = fx_codegen_and_compile(gm, example_inputs, **fx_kwargs)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\compile_fx.py", line 878, in fx_codegen_and_compile
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = graph.compile_to_fn()
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1913, in compile_to_fn
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self.compile_to_module().call
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1839, in compile_to_module
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._compile_to_module()
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1845, in _compile_to_module
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.codegen_with_cpp_wrapper() if self.cpp_wrapper else self.codegen()
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                                                              ^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\graph.py", line 1780, in codegen
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.scheduler = Scheduler(self.operations)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1731, in __init__
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self._init(nodes)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in _init
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1749, in <listcomp>
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.nodes = [self.create_scheduler_node(n) for n in nodes]
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 1856, in create_scheduler_node
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return SchedulerNode(self, node)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 833, in __init__
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self._compute_attrs()
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 846, in _compute_attrs
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     group_fn = self.scheduler.get_backend(self.node.get_device()).group_fn
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 3360, in get_backend
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.backends[device] = self.create_backend(device)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_inductor\scheduler.py", line 3352, in create_backend
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     raise RuntimeError(
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] The above exception was the direct cause of the following exception:
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] Traceback (most recent call last):
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 1064, in __call__
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     result = self._inner_convert(
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]              ^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 526, in __call__
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile(
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 924, in _compile
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 666, in compile_inner
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return _compile_inner(code, one_graph, hooks, transform)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_utils_internal.py", line 87, in wrapper_function
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return function(*args, **kwargs)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 699, in _compile_inner
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     out_code = transform_code_object(code, transform)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1322, in transform_code_object
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     transformations(instructions, code_options)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 219, in _fn
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return fn(*args, **kwargs)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\convert_frame.py", line 634, in transform
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     tracer.run()
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2796, in run
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     super().run()
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 983, in run
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     while self.step():
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]           ^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 895, in step
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.dispatch_table[inst.opcode](self, inst)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2987, in RETURN_VALUE
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self._return(inst)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2972, in _return
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.output.compile_subgraph(
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1142, in compile_subgraph
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     self.compile_and_call_fx_graph(tx, pass2.graph_output_vars(), root)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1369, in compile_and_call_fx_graph
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     compiled_fn = self.call_user_compiler(gm)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1416, in call_user_compiler
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     return self._call_user_compiler(gm)
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]   File "c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_dynamo\output_graph.py", line 1465, in _call_user_compiler
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]     raise BackendCompilerFailed(self.compiler_fn, e) from e
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] RuntimeError: Cannot find a working triton installation. Either the package is not installed or it is too old. More information on installing Triton can be found at https://github.com/openai/triton
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0124 02:16:43.047000 11248 site-packages\torch\_dynamo\convert_frame.py:1125]
# TrainOutput(global_step=6600, training_loss=0.7731756973266601, metrics={'train_runtime': 60730.4745, 'train_samples_per_second': 0.869, 'train_steps_per_second': 0.109, 'total_flos': 1559108853891072.0, 'train_loss': 0.7731756973266601, 'epoch': 3.0})

# %%
tokenizer.save_pretrained(repository_id)
trainer.create_model_card()
trainer.push_to_hub()
# Out:
# events.out.tfevents.1737654874.DESKTOP-ER3Q3E9.11248.0:   0%|          | 0.00/15.2k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Glebosol/spb_city_prob_class/commit/3343aa59eee38d2c7298c40e4b4209ac88ccbb9b', commit_message='End of training', commit_description='', oid='3343aa59eee38d2c7298c40e4b4209ac88ccbb9b', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Glebosol/spb_city_prob_class', endpoint='https://huggingface.co', repo_type='model', repo_id='Glebosol/spb_city_prob_class'), pr_revision=None, pr_num=None)
